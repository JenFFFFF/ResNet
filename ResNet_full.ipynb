# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !rm *
# !wget http://140.114.28.196/file/train.zip 
# !wget http://140.114.28.196/file/val.zip 
# !wget http://140.114.28.196/file/train.txt
# !unzip -q train.zip
# !unzip -q -f val.zip

# !ls

# %%
import tensorflow as tf
import numpy as np
import os, pdb
import cv2
import numpy as np
import random as rn
import tensorflow as tf
import threading
import time

# !unzip "/content/drive/My Drive/images.zip"


global n_classes, layer_count 
n_classes = 50
layer_count = 0

'''
LOG_DIR = '/tmp/log2'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)

#======================Only needed in colab===================================
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip -o ngrok-stable-linux-amd64.zip
get_ipython().system_raw('./ngrok http 6006 &')
# !curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
#======================Only needed in colab===================================
'''
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#==========================================================================
#=============Reading data in multithreading manner========================
#==========================================================================
def read_labeled_image_list(image_list_file, training_img_dir):
    """Reads a .txt file containing pathes and labeles
    Args:
       image_list_file: a .txt file with one /path/to/image per line
       label: optionally, if set label will be pasted after each line
    Returns:
       List with all filenames in file image_list_file
    """
    f = open(image_list_file, 'r')
    filenames = []
    labels = []

    for line in f:
        filename, label = line[:-1].split(' ')
        filename = training_img_dir+filename
        filenames.append(filename)
        labels.append(int(label))
        
    return filenames, labels
    
    
def read_images_from_disk(input_queue, size1=256):
    """Consumes a single filename and label as a ' '-delimited string.
    Args:
      filename_and_label_tensor: A scalar string tensor.
    Returns:
      Two tensors: the decoded image, and the string label.
    """
    label = input_queue[1]
    fn=input_queue[0]
    file_contents = tf.read_file(input_queue[0])
    example = tf.image.decode_jpeg(file_contents, channels=3)
    
    #example = tf.image.decode_png(file_contents, channels=3, name="dataset_image") # png fo rlfw
    example=tf.image.resize_images(example, [size1,size1])
    return example, label, fn

def setup_inputs(sess, filenames, training_img_dir, image_size=256, crop_size=224, isTest=False, batch_size=64):
    
    # Read each image file
    image_list, label_list = read_labeled_image_list(filenames, training_img_dir)

    images = tf.cast(image_list, tf.string)
    labels = tf.cast(label_list, tf.int64)
     # Makes an input queue
    if isTest is False:
        isShuffle = True
        numThr = 4
    else:
        isShuffle = False
        numThr = 1
        
    input_queue = tf.train.slice_input_producer([images, labels], shuffle=isShuffle)
    image, y,fn = read_images_from_disk(input_queue)

    channels = 3
    image.set_shape([None, None, channels])
        
    # Crop and other random augmentations
    if isTest is False:
        image = tf.image.random_flip_left_right(image)
        image = tf.image.random_flip_up_down(image)
        image = tf.image.random_hue(image,0.05)
        image = tf.image.random_saturation(image, .95, 1.05)
        image = tf.image.random_brightness(image, .05)
        image = tf.image.random_contrast(image, .95, 1.05)
    
        

    image = tf.random_crop(image, [crop_size, crop_size, 3])
    image = tf.cast(image, tf.float32)/255.0
    
    image, y,fn = tf.train.batch([image, y, fn], batch_size=batch_size, capacity=batch_size*3, num_threads=numThr, name='labels_and_images')

    tf.train.start_queue_runners(sess=sess)

    return image, y, fn, len(label_list)

# %%
def initializer(in_filters, out_filters,name='wb', ks=3):
    W = tf.get_variable(name+"W", [3,3, in_filters,out_filters], initializer=tf.truncated_normal_initializer())
    b = tf.get_variable(name+"B", [out_filters], initializer=tf.truncated_normal_initializer())
    return W, b

def activation(x,name="activation"):
    return tf.nn.relu(x, name=name)
    
def conv2d(name, l_input, w, b, s, p):
    l_input = tf.nn.conv2d(l_input, w, strides=[1,s,s,1], padding=p, name=name)
    l_input = l_input+b

    return l_input

def max_pool(name, l_input, k, s):
    return tf.nn.max_pool(l_input, ksize=[1, k, k, 1], strides=[1, s, s, 1], padding='VALID', name=name)

def batchnorm(conv, isTraining, name='bn'):
    return tf.layers.batch_normalization(conv, momentum = 0.997, training=isTraining, name="bn"+name)

# %%
  
def residual_block(in_x, in_filters, out_filters, stride, tst, name):
    # first convolution layer
    global layer_count
  
    w1, b1 = initializer(in_filters, in_filters, name=name+'wb1')
    
    x = conv2d(name+'r1', in_x, w1, b1, stride, "SAME")
    x = activation(x)   
    layer_count+=1
    print("Layer [%d] " % (layer_count) , x.get_shape().as_list())
    
    # second convolution layer
    w2, b2 = initializer(in_filters, out_filters, name=name+'wb2')
    
    x = conv2d(name+'r2', x, w2, b2, stride, "SAME")
    x = batchnorm(x, tst, name=name+"bn1-2")
    x = activation(x)
    layer_count+=1
    print("Layer [%d] " % (layer_count) , x.get_shape().as_list())
    
    if in_filters != out_filters:
#         w3, b3 = initializer(in_filters, out_filters, name=name+'trans', ks=1)
#         identity = conv2d(name+'r3', in_x, w3, b3, 1, "SAME")
#         layer_count+=1
        print("Layer [%d] " % (layer_count) , identity.get_shape().as_list())
        difference = out_filters - in_filters
        left_pad = difference // 2
        right_pad = difference - left_pad
        identity = tf.pad(in_x, [[0, 0], [0, 0], [0, 0], [left_pad, right_pad]])
        return identity + x 
    else:
        return in_x + x

      
def ResNet(_X, tst):
    global n_classes
    w1 = tf.get_variable("firstW", [7,7,3, 64], initializer=tf.truncated_normal_initializer())
    b1 = tf.get_variable("firstB", [64], initializer=tf.truncated_normal_initializer())
    
    x = conv2d('conv1', _X, w1, b1, 3, "VALID")
    x = batchnorm(x, tst, name='sbn')
    x= tf.nn.relu(x)
    
    filters_num = [64,128,256,512]
    block_num = [3,4,6,3]
    strides=[1,1,1,1]
    l_cnt = 1
    for i in range(len(filters_num)):
      for j in range(block_num[i]):
          x = residual_block(x, filters_num[i], filters_num[i], strides[i], tst, 'RB%d_%d'%(i,j))
          print('[L-%d] Build %dth residual block %d with %d channels' % (l_cnt,i, j, filters_num[i]))
          l_cnt +=1
          if ((j==block_num[i]-1) & (i<len(filters_num)-1)):
            x = batchnorm(x, tst, name='RB_bn%d_%d'%(i,j))
            w1, b1 = initializer(filters_num[i], filters_num[i+1], name='RB_pool%d_%d'%(i,j))
            x = conv2d('RB_pool%d_%d'%(i,j), x, w1, b1, 2, "VALID")
            x = activation(x)
            print('[L-%d] Build %dth connection layer %d from %d to %d channels' % (l_cnt, i, j, filters_num[i], filters_num[i+1]))
            l_cnt +=1

    wo, bo=initializer(filters_num[-1], n_classes, name='final_wb')
    x = conv2d('final', x, wo, bo, 1, "SAME")
    x = batchnorm(x, tst, name="final_bn1")
    x = activation(x, name='final_act')
    
    x = tf.reduce_mean(x, [1,2]) #b x7 x 7 x 50 ==> b x 1 x 1 x 50==>b x 50 ==> b x 50
    W = tf.get_variable("FinalW", [n_classes, n_classes], initializer=tf.truncated_normal_initializer())
    b = tf.get_variable("FinalB", [n_classes], initializer=tf.truncated_normal_initializer())
    
    out = tf.matmul(x, W) + b
                            

    return out

# %%
batch_size = 64
display_step = 80
learning_rate = tf.placeholder(tf.float32)      # Learning rate to be fed
lr = 1e-3              # Learning rate start
tst = tf.placeholder(tf.bool)

# %%
# Setup the tensorflow...
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

print("Preparing the training & validation data...")
train_data, train_labels, filelist1, glen1 = setup_inputs(sess, "train.txt", "", batch_size=batch_size)
val_data, val_labels, filelist2, tlen1 = setup_inputs(sess, "val.txt", "",isTest=True, batch_size=batch_size)

max_iter = glen1*400
print("Preparing the training model with learning rate = %.5f..." % (lr))


with tf.variable_scope("ResNet") as scope:
  pred = ResNet(train_data, True)
  scope.reuse_variables()
  valpred = ResNet(val_data, False)

with tf.name_scope('Loss_and_Accuracy'):
  update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
  with tf.control_dependencies(update_ops):
    cost = tf.losses.sparse_softmax_cross_entropy(labels=train_labels, logits=pred)
    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)
    
  correct_prediction = tf.equal(tf.argmax(pred, 1), train_labels)
  accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

  
  correct_prediction2 = tf.equal(tf.argmax(valpred,1), val_labels)
  accuracy2 = tf.reduce_mean(tf.cast(correct_prediction2, tf.float32))
  
  tf.summary.scalar('Loss', cost)
  tf.summary.scalar('Training_Accuracy', accuracy)
# Out:
# Preparing the training & validation data...
# WARNING: Logging before flag parsing goes to stderr.
# W0724 10:00:52.177865 139869006890880 deprecation.py:323] From <ipython-input-4-4690a01bcc50>:53: slice_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(tuple(tensor_list)).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# W0724 10:00:52.187494 139869006890880 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:374: range_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.range(limit).shuffle(limit).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# W0724 10:00:52.210675 139869006890880 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:320: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# W0724 10:00:52.218335 139869006890880 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:190: limit_epochs (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensors(tensor).repeat(num_epochs)`.
# W0724 10:00:52.224756 139869006890880 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:199: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W0724 10:00:52.229970 139869006890880 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:199: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W0724 10:00:52.319576 139869006890880 deprecation.py:323] From <ipython-input-4-4690a01bcc50>:73: batch (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.batch(batch_size)` (or `padded_batch(...)` if `dynamic_pad=True`).
# W0724 10:00:52.334893 139869006890880 deprecation.py:323] From <ipython-input-4-4690a01bcc50>:75: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# Preparing the training model with learning rate = 0.00100...
# W0724 10:00:54.038950 139869006890880 deprecation.py:323] From <ipython-input-5-a437f7771a6d>:19: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# Layer [1]  [64, 73, 73, 64]
# Layer [2]  [64, 73, 73, 64]
# [L-1] Build 0th residual block 0 with 64 channels
# Layer [3]  [64, 73, 73, 64]
# Layer [4]  [64, 73, 73, 64]
# [L-2] Build 0th residual block 1 with 64 channels
# Layer [5]  [64, 73, 73, 64]
# Layer [6]  [64, 73, 73, 64]
# [L-3] Build 0th residual block 2 with 64 channels
# [L-4] Build 0th connection layer 2 from 64 to 128 channels
# Layer [7]  [64, 36, 36, 128]
# Layer [8]  [64, 36, 36, 128]
# [L-5] Build 1th residual block 0 with 128 channels
# Layer [9]  [64, 36, 36, 128]
# Layer [10]  [64, 36, 36, 128]
# [L-6] Build 1th residual block 1 with 128 channels
# Layer [11]  [64, 36, 36, 128]
# Layer [12]  [64, 36, 36, 128]
# [L-7] Build 1th residual block 2 with 128 channels
# Layer [13]  [64, 36, 36, 128]
# Layer [14]  [64, 36, 36, 128]
# [L-8] Build 1th residual block 3 with 128 channels
# [L-9] Build 1th connection layer 3 from 128 to 256 channels
# Layer [15]  [64, 17, 17, 256]
# Layer [16]  [64, 17, 17, 256]
# [L-10] Build 2th residual block 0 with 256 channels
# Layer [17]  [64, 17, 17, 256]
# Layer [18]  [64, 17, 17, 256]
# [L-11] Build 2th residual block 1 with 256 channels
# Layer [19]  [64, 17, 17, 256]
# Layer [20]  [64, 17, 17, 256]
# [L-12] Build 2th residual block 2 with 256 channels
# Layer [21]  [64, 17, 17, 256]
# Layer [22]  [64, 17, 17, 256]
# [L-13] Build 2th residual block 3 with 256 channels
# Layer [23]  [64, 17, 17, 256]
# Layer [24]  [64, 17, 17, 256]
# [L-14] Build 2th residual block 4 with 256 channels
# Layer [25]  [64, 17, 17, 256]
# Layer [26]  [64, 17, 17, 256]
# [L-15] Build 2th residual block 5 with 256 channels
# [L-16] Build 2th connection layer 5 from 256 to 512 channels
# Layer [27]  [64, 8, 8, 512]
# Layer [28]  [64, 8, 8, 512]
# [L-17] Build 3th residual block 0 with 512 channels
# Layer [29]  [64, 8, 8, 512]
# Layer [30]  [64, 8, 8, 512]
# [L-18] Build 3th residual block 1 with 512 channels
# Layer [31]  [64, 8, 8, 512]
# Layer [32]  [64, 8, 8, 512]
# [L-19] Build 3th residual block 2 with 512 channels
# Layer [33]  [64, 73, 73, 64]
# Layer [34]  [64, 73, 73, 64]
# [L-1] Build 0th residual block 0 with 64 channels
# Layer [35]  [64, 73, 73, 64]
# Layer [36]  [64, 73, 73, 64]
# [L-2] Build 0th residual block 1 with 64 channels
# Layer [37]  [64, 73, 73, 64]
# Layer [38]  [64, 73, 73, 64]
# [L-3] Build 0th residual block 2 with 64 channels
# [L-4] Build 0th connection layer 2 from 64 to 128 channels
# Layer [39]  [64, 36, 36, 128]
# Layer [40]  [64, 36, 36, 128]
# [L-5] Build 1th residual block 0 with 128 channels
# Layer [41]  [64, 36, 36, 128]
# Layer [42]  [64, 36, 36, 128]
# [L-6] Build 1th residual block 1 with 128 channels
# Layer [43]  [64, 36, 36, 128]
# Layer [44]  [64, 36, 36, 128]
# [L-7] Build 1th residual block 2 with 128 channels
# Layer [45]  [64, 36, 36, 128]
# Layer [46]  [64, 36, 36, 128]
# [L-8] Build 1th residual block 3 with 128 channels
# [L-9] Build 1th connection layer 3 from 128 to 256 channels
# Layer [47]  [64, 17, 17, 256]
# Layer [48]  [64, 17, 17, 256]
# [L-10] Build 2th residual block 0 with 256 channels
# Layer [49]  [64, 17, 17, 256]
# Layer [50]  [64, 17, 17, 256]
# [L-11] Build 2th residual block 1 with 256 channels
# Layer [51]  [64, 17, 17, 256]
# Layer [52]  [64, 17, 17, 256]
# [L-12] Build 2th residual block 2 with 256 channels
# Layer [53]  [64, 17, 17, 256]
# Layer [54]  [64, 17, 17, 256]
# [L-13] Build 2th residual block 3 with 256 channels
# Layer [55]  [64, 17, 17, 256]
# Layer [56]  [64, 17, 17, 256]
# [L-14] Build 2th residual block 4 with 256 channels
# Layer [57]  [64, 17, 17, 256]
# Layer [58]  [64, 17, 17, 256]
# [L-15] Build 2th residual block 5 with 256 channels
# W0724 10:00:57.064166 139869006890880 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/losses/losses_impl.py:121: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# [L-16] Build 2th connection layer 5 from 256 to 512 channels
# Layer [59]  [64, 8, 8, 512]
# Layer [60]  [64, 8, 8, 512]
# [L-17] Build 3th residual block 0 with 512 channels
# Layer [61]  [64, 8, 8, 512]
# Layer [62]  [64, 8, 8, 512]
# [L-18] Build 3th residual block 1 with 512 channels
# Layer [63]  [64, 8, 8, 512]
# Layer [64]  [64, 8, 8, 512]
# [L-19] Build 3th residual block 2 with 512 channels

# %%
saver = tf.train.Saver()
init = tf.global_variables_initializer()
sess.run(init)
step = 0
writer = tf.summary.FileWriter("/tmp/log2", sess.graph)
summaries = tf.summary.merge_all()

print("We are going to train the ImageNet model based on ResNet!!!")
while (step * batch_size) < max_iter:
    epoch1=np.floor((step*batch_size)/glen1)
    if (((step*batch_size)%glen1 < batch_size) & (lr==1e-3) & (epoch1 >2)):
        lr /= 10

    sess.run(optimizer,  feed_dict={learning_rate: lr, tst: True})

    if (step % 15000==1) & (step>15000):
        save_path = saver.save(sess, "tf_resnet_model_iter" + str(step) + ".ckpt")
        print("Model saved in file at iteration %d: %s" % (step*batch_size,save_path))

    if step % display_step == 1:
        # calculate the loss
        
        loss, acc, summaries_string = sess.run([cost, accuracy, summaries], feed_dict={ tst: True})
        print("Iter=%d/epoch=%d, Loss=%.6f, Training Accuracy=%.6f, lr=%f" % (step*batch_size, epoch1 ,loss, acc, lr))
        writer.add_summary(summaries_string, step)
        
#         if step*batch_size==82048:
#         import pdb
#         pdb.set_trace()

  
    step += 1
print("Optimization Finished!")
save_path = saver.save(sess, "tf_resnet_model.ckpt")
print("Model saved in file: %s" % save_path)
# Out:
# We are going to train the ImageNet model based on ResNet!!!
# Iter=64/epoch=0, Loss=6.600220, Training Accuracy=0.015625, lr=0.001000
# Iter=5184/epoch=0, Loss=4.119077, Training Accuracy=0.093750, lr=0.001000
# Iter=10304/epoch=0, Loss=3.752146, Training Accuracy=0.031250, lr=0.001000
# Iter=15424/epoch=0, Loss=3.765106, Training Accuracy=0.062500, lr=0.001000
# Iter=20544/epoch=0, Loss=3.724922, Training Accuracy=0.078125, lr=0.001000
# Iter=25664/epoch=0, Loss=3.419561, Training Accuracy=0.125000, lr=0.001000
# Iter=30784/epoch=0, Loss=3.615561, Training Accuracy=0.125000, lr=0.001000
# Iter=35904/epoch=0, Loss=3.378408, Training Accuracy=0.171875, lr=0.001000
# Iter=41024/epoch=0, Loss=3.473933, Training Accuracy=0.140625, lr=0.001000
# Iter=46144/epoch=0, Loss=3.421516, Training Accuracy=0.140625, lr=0.001000
# Iter=51264/epoch=0, Loss=3.200977, Training Accuracy=0.187500, lr=0.001000
# Iter=56384/epoch=0, Loss=3.284672, Training Accuracy=0.187500, lr=0.001000
# Iter=61504/epoch=0, Loss=3.469271, Training Accuracy=0.140625, lr=0.001000
# Iter=66624/epoch=1, Loss=3.329222, Training Accuracy=0.125000, lr=0.001000
# Iter=71744/epoch=1, Loss=3.494083, Training Accuracy=0.125000, lr=0.001000
# Iter=76864/epoch=1, Loss=3.313275, Training Accuracy=0.093750, lr=0.001000
# Iter=81984/epoch=1, Loss=3.061894, Training Accuracy=0.250000, lr=0.001000
# Iter=87104/epoch=1, Loss=3.131899, Training Accuracy=0.218750, lr=0.001000
# Iter=92224/epoch=1, Loss=3.147822, Training Accuracy=0.187500, lr=0.001000
# Iter=97344/epoch=1, Loss=3.134900, Training Accuracy=0.234375, lr=0.001000
# Iter=102464/epoch=1, Loss=3.163019, Training Accuracy=0.171875, lr=0.001000
# Iter=107584/epoch=1, Loss=2.866738, Training Accuracy=0.187500, lr=0.001000
# Iter=112704/epoch=1, Loss=3.073418, Training Accuracy=0.203125, lr=0.001000
# Iter=117824/epoch=1, Loss=2.939679, Training Accuracy=0.203125, lr=0.001000
# Iter=122944/epoch=1, Loss=3.388633, Training Accuracy=0.125000, lr=0.001000
# Iter=128064/epoch=2, Loss=3.208366, Training Accuracy=0.093750, lr=0.001000
# Iter=133184/epoch=2, Loss=3.087962, Training Accuracy=0.171875, lr=0.001000
# Iter=138304/epoch=2, Loss=2.855300, Training Accuracy=0.296875, lr=0.001000
# Iter=143424/epoch=2, Loss=2.689606, Training Accuracy=0.234375, lr=0.001000
# Iter=148544/epoch=2, Loss=2.819999, Training Accuracy=0.234375, lr=0.001000
# Iter=153664/epoch=2, Loss=3.344305, Training Accuracy=0.171875, lr=0.001000
# Iter=158784/epoch=2, Loss=3.033448, Training Accuracy=0.156250, lr=0.001000
# Iter=163904/epoch=2, Loss=3.010154, Training Accuracy=0.234375, lr=0.001000
# Iter=169024/epoch=2, Loss=2.855725, Training Accuracy=0.265625, lr=0.001000
# Iter=174144/epoch=2, Loss=2.626700, Training Accuracy=0.296875, lr=0.001000
# Iter=179264/epoch=2, Loss=3.039866, Training Accuracy=0.140625, lr=0.001000
# Iter=184384/epoch=2, Loss=2.649261, Training Accuracy=0.234375, lr=0.001000
# Iter=189504/epoch=2, Loss=2.657643, Training Accuracy=0.250000, lr=0.001000
# Iter=194624/epoch=3, Loss=2.692024, Training Accuracy=0.328125, lr=0.000100
# Iter=199744/epoch=3, Loss=2.633817, Training Accuracy=0.359375, lr=0.000100
# Iter=204864/epoch=3, Loss=3.007544, Training Accuracy=0.218750, lr=0.000100
# Iter=209984/epoch=3, Loss=3.007576, Training Accuracy=0.250000, lr=0.000100
# Iter=215104/epoch=3, Loss=2.661685, Training Accuracy=0.281250, lr=0.000100
# Iter=220224/epoch=3, Loss=2.555330, Training Accuracy=0.375000, lr=0.000100
# Iter=225344/epoch=3, Loss=2.631478, Training Accuracy=0.312500, lr=0.000100
# Iter=230464/epoch=3, Loss=2.696701, Training Accuracy=0.328125, lr=0.000100
# Iter=235584/epoch=3, Loss=2.826213, Training Accuracy=0.250000, lr=0.000100
# Iter=240704/epoch=3, Loss=2.942499, Training Accuracy=0.171875, lr=0.000100
# Iter=245824/epoch=3, Loss=2.697023, Training Accuracy=0.281250, lr=0.000100
# Iter=250944/epoch=3, Loss=2.294428, Training Accuracy=0.406250, lr=0.000100
# Iter=256064/epoch=4, Loss=2.583204, Training Accuracy=0.312500, lr=0.000100
# Iter=261184/epoch=4, Loss=2.762743, Training Accuracy=0.234375, lr=0.000100
# Iter=266304/epoch=4, Loss=2.519654, Training Accuracy=0.359375, lr=0.000100
# Iter=271424/epoch=4, Loss=2.483384, Training Accuracy=0.281250, lr=0.000100
# Iter=276544/epoch=4, Loss=2.562307, Training Accuracy=0.343750, lr=0.000100
# Iter=281664/epoch=4, Loss=2.655312, Training Accuracy=0.296875, lr=0.000100
# Iter=286784/epoch=4, Loss=2.732671, Training Accuracy=0.234375, lr=0.000100
# Iter=291904/epoch=4, Loss=2.756840, Training Accuracy=0.250000, lr=0.000100
# Iter=297024/epoch=4, Loss=2.970843, Training Accuracy=0.203125, lr=0.000100
# Iter=302144/epoch=4, Loss=2.601046, Training Accuracy=0.312500, lr=0.000100
# Iter=307264/epoch=4, Loss=2.931575, Training Accuracy=0.218750, lr=0.000100
# Iter=312384/epoch=4, Loss=2.734040, Training Accuracy=0.234375, lr=0.000100
# Iter=317504/epoch=5, Loss=3.070706, Training Accuracy=0.234375, lr=0.000100
# Iter=322624/epoch=5, Loss=2.638076, Training Accuracy=0.234375, lr=0.000100
# Iter=327744/epoch=5, Loss=2.563706, Training Accuracy=0.250000, lr=0.000100
# Iter=332864/epoch=5, Loss=2.851959, Training Accuracy=0.218750, lr=0.000100
# Iter=337984/epoch=5, Loss=2.752418, Training Accuracy=0.265625, lr=0.000100
# Iter=343104/epoch=5, Loss=2.511267, Training Accuracy=0.343750, lr=0.000100
# Iter=348224/epoch=5, Loss=2.547755, Training Accuracy=0.343750, lr=0.000100
# Iter=353344/epoch=5, Loss=2.609419, Training Accuracy=0.296875, lr=0.000100
# Iter=358464/epoch=5, Loss=2.836424, Training Accuracy=0.265625, lr=0.000100
# Iter=363584/epoch=5, Loss=2.524977, Training Accuracy=0.359375, lr=0.000100
# Iter=368704/epoch=5, Loss=2.850539, Training Accuracy=0.203125, lr=0.000100
# Iter=373824/epoch=5, Loss=2.764704, Training Accuracy=0.250000, lr=0.000100
# Iter=378944/epoch=5, Loss=2.658649, Training Accuracy=0.250000, lr=0.000100
# Iter=384064/epoch=6, Loss=2.950762, Training Accuracy=0.265625, lr=0.000100
# Iter=389184/epoch=6, Loss=2.550425, Training Accuracy=0.328125, lr=0.000100
# Iter=394304/epoch=6, Loss=2.505214, Training Accuracy=0.296875, lr=0.000100
# Iter=399424/epoch=6, Loss=2.456031, Training Accuracy=0.234375, lr=0.000100
# Iter=404544/epoch=6, Loss=2.422549, Training Accuracy=0.375000, lr=0.000100
# Iter=409664/epoch=6, Loss=2.740726, Training Accuracy=0.312500, lr=0.000100
# Iter=414784/epoch=6, Loss=2.614716, Training Accuracy=0.234375, lr=0.000100
# Iter=419904/epoch=6, Loss=2.716180, Training Accuracy=0.218750, lr=0.000100
# Iter=425024/epoch=6, Loss=2.602228, Training Accuracy=0.281250, lr=0.000100
# Iter=430144/epoch=6, Loss=2.455701, Training Accuracy=0.234375, lr=0.000100
# Iter=435264/epoch=6, Loss=2.727377, Training Accuracy=0.250000, lr=0.000100
# Iter=440384/epoch=6, Loss=2.439366, Training Accuracy=0.359375, lr=0.000100
# Iter=445504/epoch=7, Loss=2.630251, Training Accuracy=0.281250, lr=0.000100
# Iter=450624/epoch=7, Loss=2.343274, Training Accuracy=0.406250, lr=0.000100
# Iter=455744/epoch=7, Loss=2.638605, Training Accuracy=0.265625, lr=0.000100
# Iter=460864/epoch=7, Loss=2.809438, Training Accuracy=0.312500, lr=0.000100
# Iter=465984/epoch=7, Loss=2.348037, Training Accuracy=0.328125, lr=0.000100
# Iter=471104/epoch=7, Loss=2.738015, Training Accuracy=0.203125, lr=0.000100
# Iter=476224/epoch=7, Loss=2.590175, Training Accuracy=0.250000, lr=0.000100
# Iter=481344/epoch=7, Loss=2.780419, Training Accuracy=0.281250, lr=0.000100
# Iter=486464/epoch=7, Loss=2.255328, Training Accuracy=0.390625, lr=0.000100
# Iter=491584/epoch=7, Loss=2.738881, Training Accuracy=0.265625, lr=0.000100
# Iter=496704/epoch=7, Loss=2.591653, Training Accuracy=0.375000, lr=0.000100
# Iter=501824/epoch=7, Loss=2.687223, Training Accuracy=0.203125, lr=0.000100
# Iter=506944/epoch=8, Loss=2.812878, Training Accuracy=0.140625, lr=0.000100
# Iter=512064/epoch=8, Loss=2.493227, Training Accuracy=0.375000, lr=0.000100
# Iter=517184/epoch=8, Loss=2.728067, Training Accuracy=0.328125, lr=0.000100
# Iter=522304/epoch=8, Loss=2.805507, Training Accuracy=0.234375, lr=0.000100
# Iter=527424/epoch=8, Loss=2.662122, Training Accuracy=0.156250, lr=0.000100
# Iter=532544/epoch=8, Loss=2.651481, Training Accuracy=0.296875, lr=0.000100
# Iter=537664/epoch=8, Loss=2.619743, Training Accuracy=0.281250, lr=0.000100
# Iter=542784/epoch=8, Loss=2.478979, Training Accuracy=0.343750, lr=0.000100
# Iter=547904/epoch=8, Loss=2.680828, Training Accuracy=0.281250, lr=0.000100
# Iter=553024/epoch=8, Loss=2.782133, Training Accuracy=0.265625, lr=0.000100
# Iter=558144/epoch=8, Loss=2.847348, Training Accuracy=0.140625, lr=0.000100
# Iter=563264/epoch=8, Loss=2.286650, Training Accuracy=0.359375, lr=0.000100
# Iter=568384/epoch=8, Loss=2.494131, Training Accuracy=0.265625, lr=0.000100
# Iter=573504/epoch=9, Loss=2.732815, Training Accuracy=0.250000, lr=0.000100
# Iter=578624/epoch=9, Loss=2.561644, Training Accuracy=0.250000, lr=0.000100
# Iter=583744/epoch=9, Loss=2.535949, Training Accuracy=0.343750, lr=0.000100
# Iter=588864/epoch=9, Loss=2.596322, Training Accuracy=0.234375, lr=0.000100
# Iter=593984/epoch=9, Loss=2.777744, Training Accuracy=0.250000, lr=0.000100
# Iter=599104/epoch=9, Loss=2.488465, Training Accuracy=0.390625, lr=0.000100
# Iter=604224/epoch=9, Loss=2.569813, Training Accuracy=0.281250, lr=0.000100
# Iter=609344/epoch=9, Loss=2.607543, Training Accuracy=0.234375, lr=0.000100
# Iter=614464/epoch=9, Loss=2.452745, Training Accuracy=0.375000, lr=0.000100
# Iter=619584/epoch=9, Loss=2.418870, Training Accuracy=0.343750, lr=0.000100
# Iter=624704/epoch=9, Loss=2.355137, Training Accuracy=0.343750, lr=0.000100
# Iter=629824/epoch=9, Loss=2.471781, Training Accuracy=0.265625, lr=0.000100
# Iter=634944/epoch=10, Loss=2.417621, Training Accuracy=0.359375, lr=0.000100
# Iter=640064/epoch=10, Loss=2.715322, Training Accuracy=0.312500, lr=0.000100
# Iter=645184/epoch=10, Loss=2.800016, Training Accuracy=0.281250, lr=0.000100
# Iter=650304/epoch=10, Loss=2.705490, Training Accuracy=0.203125, lr=0.000100
# Iter=655424/epoch=10, Loss=2.570650, Training Accuracy=0.328125, lr=0.000100
# Iter=660544/epoch=10, Loss=2.578141, Training Accuracy=0.281250, lr=0.000100
# Iter=665664/epoch=10, Loss=2.605001, Training Accuracy=0.265625, lr=0.000100
# Iter=670784/epoch=10, Loss=2.503390, Training Accuracy=0.265625, lr=0.000100
# Iter=675904/epoch=10, Loss=2.708099, Training Accuracy=0.234375, lr=0.000100
# Iter=681024/epoch=10, Loss=2.299736, Training Accuracy=0.406250, lr=0.000100
# Iter=686144/epoch=10, Loss=2.684048, Training Accuracy=0.250000, lr=0.000100
# Iter=691264/epoch=10, Loss=2.543259, Training Accuracy=0.328125, lr=0.000100
# Iter=696384/epoch=10, Loss=2.500533, Training Accuracy=0.296875, lr=0.000100
# Iter=701504/epoch=11, Loss=2.536145, Training Accuracy=0.234375, lr=0.000100
# Iter=706624/epoch=11, Loss=2.672305, Training Accuracy=0.281250, lr=0.000100
# Iter=711744/epoch=11, Loss=2.543918, Training Accuracy=0.343750, lr=0.000100
# Iter=716864/epoch=11, Loss=2.424779, Training Accuracy=0.343750, lr=0.000100
# Iter=721984/epoch=11, Loss=2.639659, Training Accuracy=0.312500, lr=0.000100
# Iter=727104/epoch=11, Loss=2.360173, Training Accuracy=0.421875, lr=0.000100
# Iter=732224/epoch=11, Loss=2.580510, Training Accuracy=0.218750, lr=0.000100
# Iter=737344/epoch=11, Loss=2.551548, Training Accuracy=0.296875, lr=0.000100
# Iter=742464/epoch=11, Loss=2.776341, Training Accuracy=0.281250, lr=0.000100
# Iter=747584/epoch=11, Loss=2.623049, Training Accuracy=0.218750, lr=0.000100
# Iter=752704/epoch=11, Loss=2.318231, Training Accuracy=0.375000, lr=0.000100
# Iter=757824/epoch=11, Loss=2.479912, Training Accuracy=0.328125, lr=0.000100
# Iter=762944/epoch=12, Loss=2.297906, Training Accuracy=0.296875, lr=0.000100
# Iter=768064/epoch=12, Loss=2.876935, Training Accuracy=0.203125, lr=0.000100
# Iter=773184/epoch=12, Loss=2.531551, Training Accuracy=0.281250, lr=0.000100
# Iter=778304/epoch=12, Loss=2.528019, Training Accuracy=0.296875, lr=0.000100
# Iter=783424/epoch=12, Loss=2.429357, Training Accuracy=0.343750, lr=0.000100
# Iter=788544/epoch=12, Loss=2.340341, Training Accuracy=0.328125, lr=0.000100
# Iter=793664/epoch=12, Loss=2.517275, Training Accuracy=0.312500, lr=0.000100
# Iter=798784/epoch=12, Loss=2.688018, Training Accuracy=0.296875, lr=0.000100
# Iter=803904/epoch=12, Loss=2.468617, Training Accuracy=0.296875, lr=0.000100
# Iter=809024/epoch=12, Loss=2.522580, Training Accuracy=0.328125, lr=0.000100
# Iter=814144/epoch=12, Loss=2.801071, Training Accuracy=0.265625, lr=0.000100
# Iter=819264/epoch=12, Loss=2.473278, Training Accuracy=0.328125, lr=0.000100
# Iter=824384/epoch=13, Loss=2.186641, Training Accuracy=0.343750, lr=0.000100
# Iter=829504/epoch=13, Loss=2.566965, Training Accuracy=0.281250, lr=0.000100
# Iter=834624/epoch=13, Loss=2.682712, Training Accuracy=0.218750, lr=0.000100
# Iter=839744/epoch=13, Loss=2.475615, Training Accuracy=0.281250, lr=0.000100
# Iter=844864/epoch=13, Loss=2.651172, Training Accuracy=0.250000, lr=0.000100
# Iter=849984/epoch=13, Loss=2.709294, Training Accuracy=0.187500, lr=0.000100
# Iter=855104/epoch=13, Loss=2.739980, Training Accuracy=0.312500, lr=0.000100
# Iter=860224/epoch=13, Loss=2.561548, Training Accuracy=0.281250, lr=0.000100
# Iter=865344/epoch=13, Loss=2.861488, Training Accuracy=0.265625, lr=0.000100
# Iter=870464/epoch=13, Loss=2.799615, Training Accuracy=0.250000, lr=0.000100
# Iter=875584/epoch=13, Loss=2.346429, Training Accuracy=0.359375, lr=0.000100
# Iter=880704/epoch=13, Loss=2.769889, Training Accuracy=0.218750, lr=0.000100
# Iter=885824/epoch=13, Loss=2.521351, Training Accuracy=0.296875, lr=0.000100
# Iter=890944/epoch=14, Loss=2.463679, Training Accuracy=0.343750, lr=0.000100
# Iter=896064/epoch=14, Loss=2.600059, Training Accuracy=0.312500, lr=0.000100
# Iter=901184/epoch=14, Loss=2.588325, Training Accuracy=0.296875, lr=0.000100
# Iter=906304/epoch=14, Loss=2.544921, Training Accuracy=0.328125, lr=0.000100
# Iter=911424/epoch=14, Loss=2.858739, Training Accuracy=0.250000, lr=0.000100
# Iter=916544/epoch=14, Loss=2.513890, Training Accuracy=0.296875, lr=0.000100
# Iter=921664/epoch=14, Loss=2.635956, Training Accuracy=0.250000, lr=0.000100
# Iter=926784/epoch=14, Loss=2.388526, Training Accuracy=0.359375, lr=0.000100
# Iter=931904/epoch=14, Loss=2.596089, Training Accuracy=0.281250, lr=0.000100
# Iter=937024/epoch=14, Loss=2.551931, Training Accuracy=0.312500, lr=0.000100
# Iter=942144/epoch=14, Loss=3.830320, Training Accuracy=0.062500, lr=0.000100
# Iter=947264/epoch=14, Loss=2.325551, Training Accuracy=0.281250, lr=0.000100
# Iter=952384/epoch=15, Loss=2.809416, Training Accuracy=0.250000, lr=0.000100
# Iter=957504/epoch=15, Loss=2.239086, Training Accuracy=0.375000, lr=0.000100
# Model saved in file at iteration 960064: tf_resnet_model_iter15001.ckpt
# Iter=962624/epoch=15, Loss=2.462583, Training Accuracy=0.296875, lr=0.000100
# Iter=967744/epoch=15, Loss=2.754470, Training Accuracy=0.328125, lr=0.000100
# Iter=972864/epoch=15, Loss=2.264354, Training Accuracy=0.343750, lr=0.000100
# Iter=977984/epoch=15, Loss=2.602171, Training Accuracy=0.265625, lr=0.000100
# Iter=983104/epoch=15, Loss=2.578330, Training Accuracy=0.343750, lr=0.000100
# Iter=988224/epoch=15, Loss=2.658378, Training Accuracy=0.296875, lr=0.000100
# Iter=993344/epoch=15, Loss=2.226978, Training Accuracy=0.343750, lr=0.000100
# Iter=998464/epoch=15, Loss=2.560153, Training Accuracy=0.296875, lr=0.000100
# Iter=1003584/epoch=15, Loss=2.486527, Training Accuracy=0.281250, lr=0.000100
# Iter=1008704/epoch=15, Loss=2.376323, Training Accuracy=0.296875, lr=0.000100
# Iter=1013824/epoch=16, Loss=2.347434, Training Accuracy=0.375000, lr=0.000100
# Iter=1018944/epoch=16, Loss=2.507107, Training Accuracy=0.281250, lr=0.000100
# Iter=1024064/epoch=16, Loss=2.365763, Training Accuracy=0.359375, lr=0.000100
# Iter=1029184/epoch=16, Loss=2.433995, Training Accuracy=0.343750, lr=0.000100
# Iter=1034304/epoch=16, Loss=2.382112, Training Accuracy=0.312500, lr=0.000100
# Iter=1039424/epoch=16, Loss=2.679754, Training Accuracy=0.281250, lr=0.000100
# Iter=1044544/epoch=16, Loss=2.492168, Training Accuracy=0.296875, lr=0.000100
# Iter=1049664/epoch=16, Loss=2.541275, Training Accuracy=0.265625, lr=0.000100
# Iter=1054784/epoch=16, Loss=2.113286, Training Accuracy=0.390625, lr=0.000100
# Iter=1059904/epoch=16, Loss=2.526868, Training Accuracy=0.312500, lr=0.000100
# Iter=1065024/epoch=16, Loss=2.444417, Training Accuracy=0.359375, lr=0.000100
# Iter=1070144/epoch=16, Loss=2.568443, Training Accuracy=0.296875, lr=0.000100
# Iter=1075264/epoch=16, Loss=2.588671, Training Accuracy=0.390625, lr=0.000100
# Iter=1080384/epoch=17, Loss=2.507676, Training Accuracy=0.250000, lr=0.000100
# Iter=1085504/epoch=17, Loss=2.630664, Training Accuracy=0.218750, lr=0.000100
# Iter=1090624/epoch=17, Loss=2.268532, Training Accuracy=0.343750, lr=0.000100
# Iter=1095744/epoch=17, Loss=2.581694, Training Accuracy=0.343750, lr=0.000100
# Iter=1100864/epoch=17, Loss=2.297698, Training Accuracy=0.343750, lr=0.000100
# Iter=1105984/epoch=17, Loss=2.429522, Training Accuracy=0.312500, lr=0.000100
# Iter=1111104/epoch=17, Loss=2.708066, Training Accuracy=0.265625, lr=0.000100
# Iter=1116224/epoch=17, Loss=2.518601, Training Accuracy=0.250000, lr=0.000100
# Iter=1121344/epoch=17, Loss=2.412911, Training Accuracy=0.296875, lr=0.000100
# Iter=1126464/epoch=17, Loss=2.656292, Training Accuracy=0.281250, lr=0.000100
# Iter=1131584/epoch=17, Loss=2.361238, Training Accuracy=0.328125, lr=0.000100
# Iter=1136704/epoch=17, Loss=2.835460, Training Accuracy=0.250000, lr=0.000100
# Iter=1141824/epoch=18, Loss=2.422806, Training Accuracy=0.343750, lr=0.000100
# Iter=1146944/epoch=18, Loss=2.377638, Training Accuracy=0.328125, lr=0.000100
# Iter=1152064/epoch=18, Loss=2.365160, Training Accuracy=0.281250, lr=0.000100
# Iter=1157184/epoch=18, Loss=2.358946, Training Accuracy=0.296875, lr=0.000100
# Iter=1162304/epoch=18, Loss=2.196352, Training Accuracy=0.390625, lr=0.000100
# Iter=1167424/epoch=18, Loss=2.162037, Training Accuracy=0.390625, lr=0.000100
# Iter=1172544/epoch=18, Loss=2.267980, Training Accuracy=0.359375, lr=0.000100
# Iter=1177664/epoch=18, Loss=2.545799, Training Accuracy=0.343750, lr=0.000100
# Iter=1182784/epoch=18, Loss=2.603978, Training Accuracy=0.187500, lr=0.000100
# Iter=1187904/epoch=18, Loss=2.298561, Training Accuracy=0.359375, lr=0.000100
# Iter=1193024/epoch=18, Loss=2.232067, Training Accuracy=0.359375, lr=0.000100
# Iter=1198144/epoch=18, Loss=2.316909, Training Accuracy=0.375000, lr=0.000100
# Iter=1203264/epoch=19, Loss=2.335328, Training Accuracy=0.421875, lr=0.000100
# Iter=1208384/epoch=19, Loss=2.598402, Training Accuracy=0.312500, lr=0.000100
# Iter=1213504/epoch=19, Loss=2.417444, Training Accuracy=0.375000, lr=0.000100
# Iter=1218624/epoch=19, Loss=2.380940, Training Accuracy=0.437500, lr=0.000100
# Iter=1223744/epoch=19, Loss=2.250175, Training Accuracy=0.359375, lr=0.000100
# Iter=1228864/epoch=19, Loss=2.385957, Training Accuracy=0.343750, lr=0.000100
# Iter=1233984/epoch=19, Loss=2.670788, Training Accuracy=0.250000, lr=0.000100
# Iter=1239104/epoch=19, Loss=2.271129, Training Accuracy=0.328125, lr=0.000100
# Iter=1244224/epoch=19, Loss=2.322809, Training Accuracy=0.343750, lr=0.000100
# Iter=1249344/epoch=19, Loss=2.325438, Training Accuracy=0.328125, lr=0.000100
# Iter=1254464/epoch=19, Loss=2.337419, Training Accuracy=0.328125, lr=0.000100
# Iter=1259584/epoch=19, Loss=2.440140, Training Accuracy=0.281250, lr=0.000100
# Iter=1264704/epoch=19, Loss=2.670900, Training Accuracy=0.234375, lr=0.000100
# Iter=1269824/epoch=20, Loss=2.656275, Training Accuracy=0.296875, lr=0.000100
# Iter=1274944/epoch=20, Loss=2.656347, Training Accuracy=0.234375, lr=0.000100
# Iter=1280064/epoch=20, Loss=2.482623, Training Accuracy=0.312500, lr=0.000100
# Iter=1285184/epoch=20, Loss=2.411962, Training Accuracy=0.281250, lr=0.000100
# Iter=1290304/epoch=20, Loss=2.424749, Training Accuracy=0.359375, lr=0.000100
# Iter=1295424/epoch=20, Loss=2.625318, Training Accuracy=0.296875, lr=0.000100
# Iter=1300544/epoch=20, Loss=2.418318, Training Accuracy=0.343750, lr=0.000100
# Iter=1305664/epoch=20, Loss=2.296757, Training Accuracy=0.390625, lr=0.000100
# Iter=1310784/epoch=20, Loss=2.355206, Training Accuracy=0.328125, lr=0.000100
# Iter=1315904/epoch=20, Loss=2.471867, Training Accuracy=0.390625, lr=0.000100
# Iter=1321024/epoch=20, Loss=2.544463, Training Accuracy=0.250000, lr=0.000100
# Iter=1326144/epoch=20, Loss=2.357146, Training Accuracy=0.281250, lr=0.000100
# Iter=1331264/epoch=21, Loss=2.650584, Training Accuracy=0.296875, lr=0.000100
# Iter=1336384/epoch=21, Loss=2.336078, Training Accuracy=0.328125, lr=0.000100
# Iter=1341504/epoch=21, Loss=2.177914, Training Accuracy=0.375000, lr=0.000100
# Iter=1346624/epoch=21, Loss=2.588662, Training Accuracy=0.281250, lr=0.000100
# Iter=1351744/epoch=21, Loss=2.266862, Training Accuracy=0.343750, lr=0.000100
# Iter=1356864/epoch=21, Loss=2.555936, Training Accuracy=0.250000, lr=0.000100
# Iter=1361984/epoch=21, Loss=2.375426, Training Accuracy=0.343750, lr=0.000100
# Iter=1367104/epoch=21, Loss=2.204030, Training Accuracy=0.390625, lr=0.000100
# Iter=1372224/epoch=21, Loss=2.244393, Training Accuracy=0.375000, lr=0.000100
# Iter=1377344/epoch=21, Loss=2.462316, Training Accuracy=0.312500, lr=0.000100
# Iter=1382464/epoch=21, Loss=2.493624, Training Accuracy=0.328125, lr=0.000100
# Iter=1387584/epoch=21, Loss=2.412718, Training Accuracy=0.296875, lr=0.000100
# Iter=1392704/epoch=21, Loss=2.225890, Training Accuracy=0.343750, lr=0.000100
# Iter=1397824/epoch=22, Loss=2.348470, Training Accuracy=0.343750, lr=0.000100
# Iter=1402944/epoch=22, Loss=2.090431, Training Accuracy=0.390625, lr=0.000100
# Iter=1408064/epoch=22, Loss=2.325949, Training Accuracy=0.328125, lr=0.000100
# Iter=1413184/epoch=22, Loss=2.451202, Training Accuracy=0.343750, lr=0.000100
# Iter=1418304/epoch=22, Loss=2.186873, Training Accuracy=0.359375, lr=0.000100
# Iter=1423424/epoch=22, Loss=2.595031, Training Accuracy=0.265625, lr=0.000100
# Iter=1428544/epoch=22, Loss=2.616439, Training Accuracy=0.250000, lr=0.000100
# Iter=1433664/epoch=22, Loss=2.639131, Training Accuracy=0.250000, lr=0.000100
# Iter=1438784/epoch=22, Loss=2.536213, Training Accuracy=0.265625, lr=0.000100
# Iter=1443904/epoch=22, Loss=2.189674, Training Accuracy=0.390625, lr=0.000100
# Iter=1449024/epoch=22, Loss=2.465122, Training Accuracy=0.390625, lr=0.000100
# Iter=1454144/epoch=22, Loss=2.679121, Training Accuracy=0.312500, lr=0.000100
# Iter=1459264/epoch=23, Loss=2.176176, Training Accuracy=0.406250, lr=0.000100
# Iter=1464384/epoch=23, Loss=2.375890, Training Accuracy=0.343750, lr=0.000100
# Iter=1469504/epoch=23, Loss=2.214403, Training Accuracy=0.406250, lr=0.000100
# Iter=1474624/epoch=23, Loss=2.088204, Training Accuracy=0.484375, lr=0.000100
# Iter=1479744/epoch=23, Loss=2.290920, Training Accuracy=0.296875, lr=0.000100
# Iter=1484864/epoch=23, Loss=2.334612, Training Accuracy=0.328125, lr=0.000100
# Iter=1489984/epoch=23, Loss=2.439414, Training Accuracy=0.312500, lr=0.000100
# Iter=1495104/epoch=23, Loss=2.230531, Training Accuracy=0.312500, lr=0.000100
# Iter=1500224/epoch=23, Loss=2.617054, Training Accuracy=0.250000, lr=0.000100
# Iter=1505344/epoch=23, Loss=2.579845, Training Accuracy=0.312500, lr=0.000100
# Iter=1510464/epoch=23, Loss=2.294797, Training Accuracy=0.359375, lr=0.000100
# Iter=1515584/epoch=23, Loss=2.014312, Training Accuracy=0.406250, lr=0.000100
# Iter=1520704/epoch=24, Loss=2.222841, Training Accuracy=0.359375, lr=0.000100
# Iter=1525824/epoch=24, Loss=2.154911, Training Accuracy=0.328125, lr=0.000100
# Iter=1530944/epoch=24, Loss=2.488728, Training Accuracy=0.359375, lr=0.000100
# Iter=1536064/epoch=24, Loss=2.270285, Training Accuracy=0.312500, lr=0.000100
# Iter=1541184/epoch=24, Loss=2.644079, Training Accuracy=0.281250, lr=0.000100
# Iter=1546304/epoch=24, Loss=2.306516, Training Accuracy=0.406250, lr=0.000100
# Iter=1551424/epoch=24, Loss=2.536460, Training Accuracy=0.296875, lr=0.000100
# Iter=1556544/epoch=24, Loss=2.583213, Training Accuracy=0.343750, lr=0.000100
# Iter=1561664/epoch=24, Loss=2.166726, Training Accuracy=0.421875, lr=0.000100
# Iter=1566784/epoch=24, Loss=2.329163, Training Accuracy=0.296875, lr=0.000100
# Iter=1571904/epoch=24, Loss=2.452014, Training Accuracy=0.265625, lr=0.000100
# Iter=1577024/epoch=24, Loss=2.668397, Training Accuracy=0.234375, lr=0.000100
# Iter=1582144/epoch=24, Loss=2.234711, Training Accuracy=0.328125, lr=0.000100
# Iter=1587264/epoch=25, Loss=2.350072, Training Accuracy=0.312500, lr=0.000100
# Iter=1592384/epoch=25, Loss=2.274681, Training Accuracy=0.343750, lr=0.000100
# Iter=1597504/epoch=25, Loss=2.047477, Training Accuracy=0.390625, lr=0.000100
# Iter=1602624/epoch=25, Loss=2.536543, Training Accuracy=0.250000, lr=0.000100
# Iter=1607744/epoch=25, Loss=2.406903, Training Accuracy=0.312500, lr=0.000100
# Iter=1612864/epoch=25, Loss=2.356893, Training Accuracy=0.312500, lr=0.000100
# Iter=1617984/epoch=25, Loss=2.370935, Training Accuracy=0.312500, lr=0.000100
# Iter=1623104/epoch=25, Loss=2.098461, Training Accuracy=0.453125, lr=0.000100
# Iter=1628224/epoch=25, Loss=2.268449, Training Accuracy=0.328125, lr=0.000100
# Iter=1633344/epoch=25, Loss=2.190536, Training Accuracy=0.390625, lr=0.000100
# Iter=1638464/epoch=25, Loss=2.233288, Training Accuracy=0.343750, lr=0.000100
# Iter=1643584/epoch=25, Loss=2.196912, Training Accuracy=0.375000, lr=0.000100
# Iter=1648704/epoch=26, Loss=2.338357, Training Accuracy=0.406250, lr=0.000100
# Iter=1653824/epoch=26, Loss=2.149060, Training Accuracy=0.359375, lr=0.000100
# Iter=1658944/epoch=26, Loss=2.134389, Training Accuracy=0.343750, lr=0.000100
# Iter=1664064/epoch=26, Loss=2.359189, Training Accuracy=0.390625, lr=0.000100
# Iter=1669184/epoch=26, Loss=2.548133, Training Accuracy=0.265625, lr=0.000100
# Iter=1674304/epoch=26, Loss=2.103587, Training Accuracy=0.296875, lr=0.000100
# Iter=1679424/epoch=26, Loss=2.352252, Training Accuracy=0.359375, lr=0.000100
# Iter=1684544/epoch=26, Loss=2.212802, Training Accuracy=0.328125, lr=0.000100
# Iter=1689664/epoch=26, Loss=2.350273, Training Accuracy=0.343750, lr=0.000100
# Iter=1694784/epoch=26, Loss=2.295272, Training Accuracy=0.437500, lr=0.000100
# Iter=1699904/epoch=26, Loss=2.447550, Training Accuracy=0.265625, lr=0.000100
# Iter=1705024/epoch=26, Loss=2.421699, Training Accuracy=0.312500, lr=0.000100
# Iter=1710144/epoch=27, Loss=2.458258, Training Accuracy=0.359375, lr=0.000100
# Iter=1715264/epoch=27, Loss=1.963119, Training Accuracy=0.421875, lr=0.000100
# Iter=1720384/epoch=27, Loss=2.401639, Training Accuracy=0.328125, lr=0.000100
# Iter=1725504/epoch=27, Loss=2.002102, Training Accuracy=0.359375, lr=0.000100
# Iter=1730624/epoch=27, Loss=2.271344, Training Accuracy=0.406250, lr=0.000100
# Iter=1735744/epoch=27, Loss=2.635582, Training Accuracy=0.281250, lr=0.000100
# Iter=1740864/epoch=27, Loss=2.241546, Training Accuracy=0.343750, lr=0.000100
# Iter=1745984/epoch=27, Loss=2.465478, Training Accuracy=0.265625, lr=0.000100
# Iter=1751104/epoch=27, Loss=2.350790, Training Accuracy=0.359375, lr=0.000100
# Iter=1756224/epoch=27, Loss=2.014406, Training Accuracy=0.359375, lr=0.000100
# Iter=1761344/epoch=27, Loss=2.256580, Training Accuracy=0.421875, lr=0.000100
# Iter=1766464/epoch=27, Loss=2.256242, Training Accuracy=0.343750, lr=0.000100
# Iter=1771584/epoch=27, Loss=2.410172, Training Accuracy=0.250000, lr=0.000100
# Iter=1776704/epoch=28, Loss=2.527602, Training Accuracy=0.250000, lr=0.000100
# Iter=1781824/epoch=28, Loss=2.231425, Training Accuracy=0.375000, lr=0.000100
# Iter=1786944/epoch=28, Loss=2.357280, Training Accuracy=0.359375, lr=0.000100
# Iter=1792064/epoch=28, Loss=2.355635, Training Accuracy=0.296875, lr=0.000100
# Iter=1797184/epoch=28, Loss=2.345606, Training Accuracy=0.437500, lr=0.000100
# Iter=1802304/epoch=28, Loss=2.286173, Training Accuracy=0.328125, lr=0.000100
# Iter=1807424/epoch=28, Loss=2.339533, Training Accuracy=0.343750, lr=0.000100
# Iter=1812544/epoch=28, Loss=2.648248, Training Accuracy=0.328125, lr=0.000100
# Iter=1817664/epoch=28, Loss=2.310685, Training Accuracy=0.359375, lr=0.000100
# Iter=1822784/epoch=28, Loss=2.438189, Training Accuracy=0.359375, lr=0.000100
# Iter=1827904/epoch=28, Loss=2.390112, Training Accuracy=0.218750, lr=0.000100
# Iter=1833024/epoch=28, Loss=2.149391, Training Accuracy=0.359375, lr=0.000100
# Iter=1838144/epoch=29, Loss=2.264090, Training Accuracy=0.328125, lr=0.000100
# Iter=1843264/epoch=29, Loss=2.225081, Training Accuracy=0.328125, lr=0.000100
# Iter=1848384/epoch=29, Loss=2.390530, Training Accuracy=0.296875, lr=0.000100
# Iter=1853504/epoch=29, Loss=2.062473, Training Accuracy=0.453125, lr=0.000100
# Iter=1858624/epoch=29, Loss=2.345359, Training Accuracy=0.390625, lr=0.000100
# Iter=1863744/epoch=29, Loss=2.146038, Training Accuracy=0.468750, lr=0.000100
# Iter=1868864/epoch=29, Loss=2.509129, Training Accuracy=0.343750, lr=0.000100
# Iter=1873984/epoch=29, Loss=2.098113, Training Accuracy=0.359375, lr=0.000100
# Iter=1879104/epoch=29, Loss=2.436013, Training Accuracy=0.359375, lr=0.000100
# Iter=1884224/epoch=29, Loss=2.333478, Training Accuracy=0.406250, lr=0.000100
# Iter=1889344/epoch=29, Loss=2.246266, Training Accuracy=0.343750, lr=0.000100
# Iter=1894464/epoch=29, Loss=2.253289, Training Accuracy=0.359375, lr=0.000100
# Iter=1899584/epoch=29, Loss=2.271600, Training Accuracy=0.343750, lr=0.000100
# Iter=1904704/epoch=30, Loss=2.095928, Training Accuracy=0.406250, lr=0.000100
# Iter=1909824/epoch=30, Loss=2.402254, Training Accuracy=0.359375, lr=0.000100
# Iter=1914944/epoch=30, Loss=2.623239, Training Accuracy=0.281250, lr=0.000100
# Model saved in file at iteration 1920064: tf_resnet_model_iter30001.ckpt
# Iter=1920064/epoch=30, Loss=2.266966, Training Accuracy=0.328125, lr=0.000100
# Iter=1925184/epoch=30, Loss=2.263311, Training Accuracy=0.359375, lr=0.000100
# Iter=1930304/epoch=30, Loss=2.598311, Training Accuracy=0.343750, lr=0.000100
# Iter=1935424/epoch=30, Loss=2.186101, Training Accuracy=0.453125, lr=0.000100
# Iter=1940544/epoch=30, Loss=2.135317, Training Accuracy=0.500000, lr=0.000100
# Iter=1945664/epoch=30, Loss=2.057199, Training Accuracy=0.500000, lr=0.000100
# Iter=1950784/epoch=30, Loss=2.078389, Training Accuracy=0.437500, lr=0.000100
# Iter=1955904/epoch=30, Loss=2.294862, Training Accuracy=0.359375, lr=0.000100
# Iter=1961024/epoch=30, Loss=2.385198, Training Accuracy=0.281250, lr=0.000100
# Iter=1966144/epoch=31, Loss=2.232588, Training Accuracy=0.437500, lr=0.000100
# Iter=1971264/epoch=31, Loss=2.284248, Training Accuracy=0.343750, lr=0.000100
# Iter=1976384/epoch=31, Loss=2.260411, Training Accuracy=0.203125, lr=0.000100
# Iter=1981504/epoch=31, Loss=2.236133, Training Accuracy=0.375000, lr=0.000100
# Iter=1986624/epoch=31, Loss=2.240576, Training Accuracy=0.406250, lr=0.000100
# Iter=1991744/epoch=31, Loss=2.178514, Training Accuracy=0.359375, lr=0.000100
# Iter=1996864/epoch=31, Loss=1.964479, Training Accuracy=0.375000, lr=0.000100
# Iter=2001984/epoch=31, Loss=1.977070, Training Accuracy=0.359375, lr=0.000100
# Iter=2007104/epoch=31, Loss=2.310142, Training Accuracy=0.312500, lr=0.000100
# Iter=2012224/epoch=31, Loss=2.181720, Training Accuracy=0.375000, lr=0.000100
# Iter=2017344/epoch=31, Loss=2.293966, Training Accuracy=0.406250, lr=0.000100
# Iter=2022464/epoch=31, Loss=2.216876, Training Accuracy=0.421875, lr=0.000100
# Iter=2027584/epoch=32, Loss=2.272510, Training Accuracy=0.390625, lr=0.000100
# Iter=2032704/epoch=32, Loss=2.193047, Training Accuracy=0.375000, lr=0.000100
# Iter=2037824/epoch=32, Loss=2.000896, Training Accuracy=0.484375, lr=0.000100
# Iter=2042944/epoch=32, Loss=2.331094, Training Accuracy=0.328125, lr=0.000100
# Iter=2048064/epoch=32, Loss=2.229094, Training Accuracy=0.406250, lr=0.000100
# Iter=2053184/epoch=32, Loss=2.291712, Training Accuracy=0.250000, lr=0.000100
# Iter=2058304/epoch=32, Loss=2.137830, Training Accuracy=0.406250, lr=0.000100
# Iter=2063424/epoch=32, Loss=2.248211, Training Accuracy=0.375000, lr=0.000100
# Iter=2068544/epoch=32, Loss=2.295895, Training Accuracy=0.375000, lr=0.000100
# Iter=2073664/epoch=32, Loss=2.403866, Training Accuracy=0.250000, lr=0.000100
# Iter=2078784/epoch=32, Loss=1.693453, Training Accuracy=0.546875, lr=0.000100
# Iter=2083904/epoch=32, Loss=2.162786, Training Accuracy=0.421875, lr=0.000100
# Iter=2089024/epoch=32, Loss=2.105776, Training Accuracy=0.421875, lr=0.000100
# Iter=2094144/epoch=33, Loss=2.130627, Training Accuracy=0.406250, lr=0.000100
# Iter=2099264/epoch=33, Loss=2.129727, Training Accuracy=0.359375, lr=0.000100
# Iter=2104384/epoch=33, Loss=2.563948, Training Accuracy=0.312500, lr=0.000100
# Iter=2109504/epoch=33, Loss=2.280517, Training Accuracy=0.312500, lr=0.000100
# Iter=2114624/epoch=33, Loss=2.314536, Training Accuracy=0.343750, lr=0.000100
# Iter=2119744/epoch=33, Loss=2.548903, Training Accuracy=0.375000, lr=0.000100
# Iter=2124864/epoch=33, Loss=2.495272, Training Accuracy=0.296875, lr=0.000100
# Iter=2129984/epoch=33, Loss=2.236477, Training Accuracy=0.406250, lr=0.000100
# Iter=2135104/epoch=33, Loss=2.306089, Training Accuracy=0.359375, lr=0.000100
# Iter=2140224/epoch=33, Loss=2.499753, Training Accuracy=0.375000, lr=0.000100
# Iter=2145344/epoch=33, Loss=2.207352, Training Accuracy=0.390625, lr=0.000100
# Iter=2150464/epoch=33, Loss=2.054784, Training Accuracy=0.468750, lr=0.000100
# Iter=2155584/epoch=34, Loss=2.012465, Training Accuracy=0.453125, lr=0.000100
# Iter=2160704/epoch=34, Loss=1.912889, Training Accuracy=0.437500, lr=0.000100
# Iter=2165824/epoch=34, Loss=2.071212, Training Accuracy=0.406250, lr=0.000100
# Iter=2170944/epoch=34, Loss=2.591363, Training Accuracy=0.312500, lr=0.000100
# Iter=2176064/epoch=34, Loss=2.282148, Training Accuracy=0.343750, lr=0.000100
# Iter=2181184/epoch=34, Loss=2.583413, Training Accuracy=0.359375, lr=0.000100
# Iter=2186304/epoch=34, Loss=2.088931, Training Accuracy=0.437500, lr=0.000100
# Iter=2191424/epoch=34, Loss=2.186925, Training Accuracy=0.406250, lr=0.000100
# Iter=2196544/epoch=34, Loss=2.492768, Training Accuracy=0.328125, lr=0.000100
# Iter=2201664/epoch=34, Loss=2.073065, Training Accuracy=0.406250, lr=0.000100
# Iter=2206784/epoch=34, Loss=2.369452, Training Accuracy=0.234375, lr=0.000100
# Iter=2211904/epoch=34, Loss=2.442609, Training Accuracy=0.328125, lr=0.000100
# Iter=2217024/epoch=35, Loss=2.181448, Training Accuracy=0.406250, lr=0.000100
# Iter=2222144/epoch=35, Loss=2.357131, Training Accuracy=0.328125, lr=0.000100
# Iter=2227264/epoch=35, Loss=2.016428, Training Accuracy=0.375000, lr=0.000100
# Iter=2232384/epoch=35, Loss=2.323207, Training Accuracy=0.265625, lr=0.000100
# Iter=2237504/epoch=35, Loss=2.318011, Training Accuracy=0.359375, lr=0.000100
# Iter=2242624/epoch=35, Loss=2.355598, Training Accuracy=0.390625, lr=0.000100
# Iter=2247744/epoch=35, Loss=2.406346, Training Accuracy=0.328125, lr=0.000100
# Iter=2252864/epoch=35, Loss=2.126770, Training Accuracy=0.437500, lr=0.000100
# Iter=2257984/epoch=35, Loss=2.429601, Training Accuracy=0.296875, lr=0.000100
# Iter=2263104/epoch=35, Loss=2.113403, Training Accuracy=0.375000, lr=0.000100
# Iter=2268224/epoch=35, Loss=2.158186, Training Accuracy=0.468750, lr=0.000100
# Iter=2273344/epoch=35, Loss=2.184885, Training Accuracy=0.453125, lr=0.000100
# Iter=2278464/epoch=35, Loss=2.395391, Training Accuracy=0.265625, lr=0.000100
# Iter=2283584/epoch=36, Loss=2.170703, Training Accuracy=0.343750, lr=0.000100
# Iter=2288704/epoch=36, Loss=2.235213, Training Accuracy=0.421875, lr=0.000100
# Iter=2293824/epoch=36, Loss=2.108556, Training Accuracy=0.515625, lr=0.000100
# Iter=2298944/epoch=36, Loss=1.940103, Training Accuracy=0.437500, lr=0.000100
# Iter=2304064/epoch=36, Loss=2.045907, Training Accuracy=0.421875, lr=0.000100
# Iter=2309184/epoch=36, Loss=2.139324, Training Accuracy=0.375000, lr=0.000100
# Iter=2314304/epoch=36, Loss=2.162762, Training Accuracy=0.390625, lr=0.000100
# Iter=2319424/epoch=36, Loss=1.891300, Training Accuracy=0.546875, lr=0.000100
# Iter=2324544/epoch=36, Loss=2.530708, Training Accuracy=0.328125, lr=0.000100
# Iter=2329664/epoch=36, Loss=2.066570, Training Accuracy=0.437500, lr=0.000100
# Iter=2334784/epoch=36, Loss=1.991902, Training Accuracy=0.406250, lr=0.000100
# Iter=2339904/epoch=36, Loss=2.191079, Training Accuracy=0.421875, lr=0.000100
# Iter=2345024/epoch=37, Loss=2.078953, Training Accuracy=0.437500, lr=0.000100
# Iter=2350144/epoch=37, Loss=2.096828, Training Accuracy=0.421875, lr=0.000100
# Iter=2355264/epoch=37, Loss=2.418051, Training Accuracy=0.281250, lr=0.000100
# Iter=2360384/epoch=37, Loss=2.347435, Training Accuracy=0.265625, lr=0.000100
# Iter=2365504/epoch=37, Loss=2.376595, Training Accuracy=0.312500, lr=0.000100
# Iter=2370624/epoch=37, Loss=2.132734, Training Accuracy=0.390625, lr=0.000100
# Iter=2375744/epoch=37, Loss=2.209945, Training Accuracy=0.328125, lr=0.000100
# Iter=2380864/epoch=37, Loss=1.906175, Training Accuracy=0.484375, lr=0.000100
# Iter=2385984/epoch=37, Loss=2.243503, Training Accuracy=0.234375, lr=0.000100
# Iter=2391104/epoch=37, Loss=2.268336, Training Accuracy=0.421875, lr=0.000100
# Iter=2396224/epoch=37, Loss=1.746909, Training Accuracy=0.484375, lr=0.000100
# Iter=2401344/epoch=37, Loss=1.819080, Training Accuracy=0.453125, lr=0.000100
# Iter=2406464/epoch=38, Loss=2.257386, Training Accuracy=0.343750, lr=0.000100
# Iter=2411584/epoch=38, Loss=2.096581, Training Accuracy=0.343750, lr=0.000100
# Iter=2416704/epoch=38, Loss=2.224648, Training Accuracy=0.390625, lr=0.000100
# Iter=2421824/epoch=38, Loss=2.065799, Training Accuracy=0.453125, lr=0.000100
# Iter=2426944/epoch=38, Loss=2.319534, Training Accuracy=0.359375, lr=0.000100
# Iter=2432064/epoch=38, Loss=2.004995, Training Accuracy=0.453125, lr=0.000100
# Iter=2437184/epoch=38, Loss=2.147568, Training Accuracy=0.375000, lr=0.000100
# Iter=2442304/epoch=38, Loss=2.416384, Training Accuracy=0.359375, lr=0.000100
# Iter=2447424/epoch=38, Loss=2.496910, Training Accuracy=0.296875, lr=0.000100
# Iter=2452544/epoch=38, Loss=2.011547, Training Accuracy=0.437500, lr=0.000100
# Iter=2457664/epoch=38, Loss=2.052921, Training Accuracy=0.390625, lr=0.000100
# Iter=2462784/epoch=38, Loss=2.400189, Training Accuracy=0.343750, lr=0.000100
# Iter=2467904/epoch=38, Loss=2.126612, Training Accuracy=0.359375, lr=0.000100

# %%
exit()
